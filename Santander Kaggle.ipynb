# %%
from __future__ import division
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

print(os.getcwd() + "\n")
# Out:
# /Users/george/Documents/Spring 2016/Machine Learning-Anurag Nagar/project

# %%
#Ionosphere data set
santander_df = pd.read_csv("/Users/george/Documents/Spring 2016/Machine Learning-Anurag Nagar/project/train.csv", parse_dates="True")

# %%
# count =0
# for col in santander_df.columns:
#     print santander_df[col].isnull().sum()

# %%
# The list of all columns, so that we know to drop meaningless ones
for col in santander_df.columns:
    print col
# Out:
# var3
# var15
# imp_ent_var16_ult1
# imp_op_var39_comer_ult1
# imp_op_var39_comer_ult3
# imp_op_var40_comer_ult1
# imp_op_var40_comer_ult3
# imp_op_var40_efect_ult1
# imp_op_var40_efect_ult3
# imp_op_var40_ult1
# imp_op_var41_comer_ult1
# imp_op_var41_comer_ult3
# imp_op_var41_efect_ult1
# imp_op_var41_efect_ult3
# imp_op_var41_ult1
# imp_op_var39_efect_ult1
# imp_op_var39_efect_ult3
# imp_op_var39_ult1
# imp_sal_var16_ult1
# ind_var1_0
# ind_var1
# ind_var2_0
# ind_var2
# ind_var5_0
# ind_var5
# ind_var6_0
# ind_var6
# ind_var8_0
# ind_var8
# ind_var12_0
# ind_var12
# ind_var13_0
# ind_var13_corto_0
# ind_var13_corto
# ind_var13_largo_0
# ind_var13_largo
# ind_var13_medio_0
# ind_var13_medio
# ind_var13
# ind_var14_0
# ind_var14
# ind_var17_0
# ind_var17
# ind_var18_0
# ind_var18
# ind_var19
# ind_var20_0
# ind_var20
# ind_var24_0
# ind_var24
# ind_var25_cte
# ind_var26_0
# ind_var26_cte
# ind_var26
# ind_var25_0
# ind_var25
# ind_var27_0
# ind_var28_0
# ind_var28
# ind_var27
# ...

# %%
santander_df.drop("ID",inplace=True, axis=1)

# %%
santander_df
# Out:
#        var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 0         2     23                   0                     0.00
# 1         2     34                   0                     0.00
# 2         2     23                   0                     0.00
# 3         2     37                   0                   195.00
# 4         2     39                   0                     0.00
# 5         2     23                   0                     0.00
# 6         2     27                   0                     0.00
# 7         2     26                   0                     0.00
# 8         2     45                   0                     0.00
# 9         2     25                   0                     0.00
# 10        2     42                   0                     0.00
# 11        2     26                   0                     0.00
# 12        2     51                   0                     0.00
# 13        2     43                   0                     0.00
# ...

# %%
# Importing the algorithms required to run
from sklearn.cross_validation import train_test_split, StratifiedShuffleSplit, LeaveOneOut

from sklearn import tree

from sklearn.linear_model import Perceptron


#Install the latest dev version 0.18dev to get neural network code with the following instructions below

# http://stackoverflow.com/questions/33568244/upgrade-to-dev-version-of-scikit-learn-on-anaconda
# pip install git+git://github.com/scikit-learn/scikit-learn.git
# This command runs perfectly fine on a MAC.

# After installation shut down and open ipython and run the code again to see the import working perfectly fine.

from sklearn.neural_network import MLPClassifier

from sklearn import svm

from sklearn.naive_bayes import GaussianNB


from hmmlearn import hmm

# %%
# data_frame_map = {"Santander dataset" : santander_df}

# Map of all the five classifiers to help in accuracy printing
classifier_map = {#"Decision Tree " : tree.DecisionTreeClassifier(),
                   #"Perceptron " : Perceptron(fit_intercept=False, n_iter=10, shuffle=False),
                   #"Neural Network " : MLPClassifier(algorithm='sgd', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1),
                   #"Support Vector Machines" : svm.SVC(),
                   "Naive Bayes" :GaussianNB()}

# %%
#Implementing the pseudo code.


classLabel = santander_df.pop('TARGET')
print ("Number of instances and number of attributes in Santander dataset are %d and %d" % (len(santander_df.axes[0]),len(santander_df.axes[1])))
f = open('ReportOfRunningScript.txt','w')
f.write("Number of instances and number of attributes in Santander dataset are %d and %d" % (len(santander_df.axes[0]),len(santander_df.axes[1])))
f.close()

# Variable to initialize random_state attribute to select different train test split each time. Used in splitting inside the loop.
random_sample_selection_number = [42, 17]
Xtrain, Xtest, ytrain, ytest = train_test_split(santander_df,classLabel,test_size=0.1,random_state=random_sample_selection_number.pop())

clf = GaussianNB().fit(Xtrain, ytrain)
score = clf.score(Xtest,ytest)
print("Accuracy of Santander dataset after running with Naive Bayes algorithm is %f" % (score))
f = open('ReportOfRunningScript.txt','a')
f.write("Accuracy of Santander dataset after running with Naive Bayes algorithm is %f" % (score))
f.close()
# Out:
# Number of instances and number of attributes in Santander dataset are 76020 and 369
# Accuracy of Santander dataset after running with Naive Bayes algorithm is 0.059853

# %% [markdown]
# #Feature importances

# %%
plt.figure(figsize=(10,9))
perm = np.argsort(clf.feature_importances_)
plt.barh(range(len(data_frame_map.columns)),clf.feature_importances_[perm], align='center')
plt.yticks(range(len(data_frame_map.columns)),data_frame_map.columns[perm], size=13, ha='right')
plt.xlabel('Relative Importance in the Naive Bayes classifier')
plt.title('Relative importances of features', size=17)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-927a765461e9> in <module>()
#       1
#       2 plt.figure(figsize=(10,9))
# ----> 3 perm = np.argsort(clf.feature_importances_)
#       4 plt.barh(range(len(data_frame_map.columns)),clf.feature_importances_[perm], align='center')
#       5 plt.yticks(range(len(data_frame_map.columns)),data_frame_map.columns[perm], size=13, ha='right')
#
# AttributeError: 'GaussianNB' object has no attribute 'feature_importances_'

# %%
clf.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-2f093d6d846a> in <module>()
# ----> 1 clf.feature_importances_
#
# AttributeError: 'GaussianNB' object has no attribute 'feature_importances_'
